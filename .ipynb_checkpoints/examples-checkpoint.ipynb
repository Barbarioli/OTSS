# %% [markdown]
# # Subsampler examples

# %% [markdown]
# ## Packages and modules

# %%
import multiprocessing as mp
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import sys
import warnings
import os
from random import randint
from scipy.ndimage.filters import uniform_filter1d
from numpy.random import normal
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.arima_process import arma_generate_sample
#from statsmodels.tsa.arima_model import 

if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %%
os.getcwd()
# Out:
# '/Users/brunobarbarioli/Documents/Research/OTSS'

# %%
from algorithms.online_subsampler import *
from algorithms.analytics import *
from algorithms.breakpoint_detection import *
from algorithms.empirical_bernstein import *
from algorithms.uniform_subsampler import *
from algorithms.queries import *
from algorithms.size_optimizer import *

# %% [markdown]
# ## AR(1)

# %%
#Piecewise Stationary series

#Parameters
n = 100000
mu = 2
sigma = 0.5

ar = np.array([1,0.5])
ma = np.array([1])
time_series = ArmaProcess(-ar,ma)
time_series_values = time_series.generate_sample(n)

#Altered means
time_series_values[:] += 7.5
time_series_values[10000:20000] += 10
time_series_values[40000:50000] += 5
time_series_values[60000:70000] += 10
time_series_values[80000:90000] += 7.5

#plot
tidx = pd.date_range('1950-01-01', periods=n, freq='D') # freq='MS'set the frequency of date in months and start from day 1. You can use 'T' for minutes and so on
series = pd.Series(time_series_values, index =tidx)
series.plot(figsize=(10, 5))

# %%
# Online subsampler

queue = mp.Queue()
return_queue = mp.Queue()
index_queue = mp.Queue()
p1 = mp.Process(target = detection, args = (series, queue, 8, 0.5, False, True))
p2 = mp.Process(target = online_subsampler, args = (0.15,0.01,10,50,series, queue, return_queue,index_queue, 1000))

p1.start()
p2.start()
# Out:
# breakpoint started
# subsampler started
# Interval size:  10000
# Relative sample size:  2.0 %
# ----*----
# Interval size:  10000
# Relative sample size:  2.0 %
# ----*----
# Interval size:  2659
# Relative sample size:  9.4 %
# ----*----
# Interval size:  15523
# Relative sample size:  1.61 %
# ----*----
# Interval size:  3457
# Relative sample size:  7.23 %
# ----*----
# Interval size:  9851
# Relative sample size:  2.54 %
# ----*----
# Interval size:  8510
# Relative sample size:  2.94 %
# ----*----
# Interval size:  10000
# Relative sample size:  2.5 %
# ----*----
# Interval size:  10000
# Relative sample size:  2.5 %
# ----*----
# Interval size:  20000
# Relative sample size:  1.25 %
# ----*----
# Done

# %%
online_subsample = retrieve_data(return_queue)
online_subsample.plot(figsize=(10, 5))

# %%
#Baseline Subsamples
online_subsample_size = len(online_subsample)
uniform_sample, eb_sample = size_optimizer(series, online_subsample_size, 10, error = 0.25)

# %%
#Comparing subsample sizes
print('Online subsample size: ', online_subsample_size)
print('EB subsample size: ',len(eb_sample))
print('Uniform subsample size: ',len(uniform_sample))
# Out:
# Online subsample size:  12815
# EB subsample size:  17166
# Uniform subsample size:  14288

# %%
#upscaled subsamples
online_sample_upscaled = online_subsample.resample('D').mean()
eb_sample_upscaled = eb_sample.resample('D').mean()
uniform_sample_upscaled = uniform_sample.resample('D').mean()

# %% [markdown]
# ### Query evaluations

# %%
#interpolation querry
#10
print('Interpolation for 57th value: \n')
print('Real value: ', series[57])
print('Empirical Bernstein: ', interpolation_query(eb_sample_upscaled, 57, method = 'linear'))
print('Uniform sampler: ', interpolation_query(uniform_sample_upscaled, 57, method = 'linear'))
print('Online Sampler:', interpolation_query(online_sample_upscaled, 57, method = 'linear'))
print('------------\n')

#17400
print('Interpolation for 17400 value: \n')
print('Real value: ', series[17401])
print('Empirical Bernstein: ', interpolation_query(eb_sample_upscaled, 17401, method = 'linear'))
print('Uniform sampler: ', interpolation_query(uniform_sample_upscaled, 17401, method = 'linear'))
print('Online Sampler:', interpolation_query(online_sample_upscaled, 17401, method = 'linear'))
print('------------\n')

#1003

print('Interpolation for 1003 value: \n')
print('Real value: ', series[1003])
print('Empirical Bernstein: ', interpolation_query(eb_sample_upscaled, 1003, method = 'linear'))
print('Uniform sampler: ', interpolation_query(uniform_sample_upscaled, 1003, method = 'linear'))
print('Online Sampler:', interpolation_query(online_sample_upscaled, 1003, method = 'linear'))
print('------------\n')

#77802

print('Interpolation for 77802 value: \n')
print('Real value: ', series[77802])
print('Empirical Bernstein: ', interpolation_query(eb_sample_upscaled, 77802, method = 'linear'))
print('Uniform sampler: ', interpolation_query(uniform_sample_upscaled, 77802, method = 'linear'))
print('Online Sampler:', interpolation_query(online_sample_upscaled, 77802, method = 'linear'))
print('------------\n')
# Out:
# Interpolation for 57th value:
#
# Real value:  8.874960878246856
# Empirical Bernstein:  8.98225311829292
# Uniform sampler:  7.692757760863409
# Online Sampler: 5.6194648606346025
# ------------
#
# Interpolation for 17400 value:
#
# Real value:  16.908145757152667
# Empirical Bernstein:  19.724244627370314
# Uniform sampler:  16.05472989437017
# Online Sampler: 16.874522944576412
# ------------
#
# Interpolation for 1003 value:
#
# Real value:  8.46383998554881
# Empirical Bernstein:  7.277436693462999
# Uniform sampler:  8.282744589650472
# Online Sampler: 6.936144103837499
# ------------
#
# Interpolation for 77802 value:
#
# Real value:  7.224373991835813
# Empirical Bernstein:  7.9513299038005005
# Uniform sampler:  6.545552911279001
# Online Sampler: 7.335059724154865
# ------------

# %%
# Distance metrics for linear interpolation

print('Euclidean distance: \n')
print('Empirical Bernstein: ', interpolation_distance(series, eb_sample_upscaled))
print('Uniform: ', interpolation_distance(series, uniform_sample_upscaled))
print('Online Sampler: \n', interpolation_distance(series, online_sample_upscaled))
print('------------ \n')

print('DTW distance: \n')
print('Empirical Bernstein: ', interpolation_distance(series, eb_sample_upscaled, distance = 'dtw'))
print('Uniform: ', interpolation_distance(series, uniform_sample_upscaled, distance = 'dtw'))
print('Online Sampler: \n', interpolation_distance(series, online_sample_upscaled, distance = 'dtw'))
print('------------\n')
# Out:
# Euclidean distance:
#
# Empirical Bernstein:  451.67750584771886
# Uniform:  456.7780837676579
# Online Sampler:
#  688.5952500602717
# ------------
#
# DTW distance:
#
# Empirical Bernstein:  104536.028457333
# Uniform:  104380.26187712287
# Online Sampler:
#  134091.33216581363
# ------------

# %%
# Autocorrelation

print('Autocorrelation: \n')
print('Original time series: ')
correlation_query(series, number_of_lags = 2, print_lags = True, plot = False)
print('Empirical Bernstein: ')
correlation_query(eb_sample, number_of_lags = 2, print_lags = True, plot = False)
print('Uniform: ' )
correlation_query(uniform_sample, number_of_lags = 2, print_lags = True, plot = False)
print('Online Sampler:', )
correlation_query(online_subsample, number_of_lags = 2, print_lags = True, plot = False)
print('------------ \n')
# Out:
# Autocorrelation:
#
# Original time series:
# lag 0:  0.893989436073809
# lag 1:  0.9465879945764605
# Empirical Bernstein:
# lag 0:  -0.008472033001418303
# lag 1:  0.0042320382958085006
# Uniform:
# lag 0:  0.9295157966735192
# lag 1:  0.9287765940049284
# Online Sampler:
# lag 0:  0.8763462343424628
# lag 1:  0.9256257848457824
# ------------

# %%
# Distance metrics for autocorrelation

print('Euclidean distance of all autocorrelation lags: \n')
print('Empirical Bernstein: ', correlation_distance(series, eb_sample, number_of_lags = 2, print_lags = False, plot = False))
print('Uniform: ', correlation_distance(series, uniform_sample, number_of_lags = 2, print_lags = False, plot = False))
print('Online Sampler: \n', correlation_distance(series, online_subsample, number_of_lags = 2, print_lags = False, plot = False))
print('------------ \n')
# Out:
# Euclidean distance of all autocorrelation lags:
#
# Empirical Bernstein:  1.3047878952163219
# Uniform:  0.03974126681146713
# Online Sampler:
#  0.027398846766349686
# ------------

# %% [markdown]
# ## AR(2)

# %%
#Piecewise Stationary series

#Parameters
n = 100000
mu = 2
sigma = 0.5

ar = np.array([1,0.75,0.5])
ma = np.array([1])
time_series = ArmaProcess(-ar,ma)
time_series_values = time_series.generate_sample(n)

#Altered means
time_series_values[:] += 7.5
time_series_values[10000:20000] += 10
time_series_values[40000:50000] += 5
time_series_values[60000:70000] += 10
time_series_values[80000:90000] += 7.5

#plot
tidx = pd.date_range('1950-01-01', periods=n, freq='D') # freq='MS'set the frequency of date in months and start from day 1. You can use 'T' for minutes and so on
series = pd.Series(time_series_values, index =tidx)
series.plot(figsize=(10, 5))

# %%
# Online subsampler

queue = mp.Queue()
return_queue = mp.Queue()
index_queue = mp.Queue()
p1 = mp.Process(target = detection, args = (series, queue, 8.25, 1, False, True))
p2 = mp.Process(target = online_subsampler, args = (0.10,0.01,10,50,series, queue, return_queue,index_queue, 1000))

p1.start()
p2.start()
# Out:
# breakpoint started
# subsampler started
# Interval size:  10000
# Relative sample size:  3.5 %
# ----*----
# Interval size:  10000
# Relative sample size:  3.0 %
# ----*----
# Interval size:  10283
# Relative sample size:  4.38 %
# ----*----
# Interval size:  21246
# Relative sample size:  2.12 %
# ----*----
# Interval size:  8471
# Relative sample size:  5.9 %
# ----*----
# Interval size:  10000
# Relative sample size:  4.0 %
# ----*----
# Interval size:  1370
# Relative sample size:  100%
# ----*----
# Interval size:  5373
# Relative sample size:  9.31 %
# ----*----
# Interval size:  5318
# Relative sample size:  9.4 %
# ----*----
# Interval size:  1530
# Relative sample size:  100%
# ----*----
# Interval size:  16409
# Relative sample size:  2.74 %
# ----*----
# Done

# %%
#Subsample data
online_subsample = retrieve_data(return_queue)
online_subsample.plot(figsize=(10, 5))

# %%
#Baseline Subsamples
online_subsample_size = len(online_subsample)
uniform_sample, eb_sample = size_optimizer(series, online_subsample_size, 10, error = 0.1)

# %%
#Comparing subsample sizes
print('Online subsample size: ', online_subsample_size)
print('EB subsample size: ',len(eb_sample))
print('Uniform subsample size: ',len(uniform_sample))
# Out:
# Online subsample size:  21419
# EB subsample size:  17652
# Uniform subsample size:  25002

# %%
#upscaled subsamples
online_sample_upscaled = online_subsample.resample('D').mean()
eb_sample_upscaled = eb_sample.resample('D').mean()
uniform_sample_upscaled = uniform_sample.resample('D').mean()

# %% [markdown]
# ### Query evaluation

# %%
#interpolation querry
#10
print('Interpolation for 57th value: \n')
print('Real value: ', series[57])
print('Empirical Bernstein: ', interpolation_query(eb_sample_upscaled, 57, method = 'linear'))
print('Uniform sampler: ', interpolation_query(uniform_sample_upscaled, 57, method = 'linear'))
print('Online Sampler:', interpolation_query(online_sample_upscaled, 57, method = 'linear'))
print('------------\n')

#17400
print('Interpolation for 17400 value: \n')
print('Real value: ', series[17401])
print('Empirical Bernstein: ', interpolation_query(eb_sample_upscaled, 17401, method = 'linear'))
print('Uniform sampler: ', interpolation_query(uniform_sample_upscaled, 17401, method = 'linear'))
print('Online Sampler:', interpolation_query(online_sample_upscaled, 17401, method = 'linear'))
print('------------\n')

#1003

print('Interpolation for 1003 value: \n')
print('Real value: ', series[1003])
print('Empirical Bernstein: ', interpolation_query(eb_sample_upscaled, 1003, method = 'linear'))
print('Uniform sampler: ', interpolation_query(uniform_sample_upscaled, 1003, method = 'linear'))
print('Online Sampler:', interpolation_query(online_sample_upscaled, 1003, method = 'linear'))
print('------------\n')

#77802

print('Interpolation for 77802 value: \n')
print('Real value: ', series[77802])
print('Empirical Bernstein: ', interpolation_query(eb_sample_upscaled, 77802, method = 'linear'))
print('Uniform sampler: ', interpolation_query(uniform_sample_upscaled, 77802, method = 'linear'))
print('Online Sampler:', interpolation_query(online_sample_upscaled, 77802, method = 'linear'))
print('------------\n')
# Out:
# Interpolation for 57th value:
#
# Real value:  7.856783591601748
# Empirical Bernstein:  8.98225311829292
# Uniform sampler:  7.692757760863409
# Online Sampler: 5.6194648606346025
# ------------
#
# Interpolation for 17400 value:
#
# Real value:  16.4526987734544
# Empirical Bernstein:  19.724244627370314
# Uniform sampler:  16.05472989437017
# Online Sampler: 16.874522944576412
# ------------
#
# Interpolation for 1003 value:
#
# Real value:  6.458478606214392
# Empirical Bernstein:  7.277436693462999
# Uniform sampler:  8.282744589650472
# Online Sampler: 6.936144103837499
# ------------
#
# Interpolation for 77802 value:
#
# Real value:  6.1285908310794746
# Empirical Bernstein:  7.9513299038005005
# Uniform sampler:  6.545552911279001
# Online Sampler: 7.335059724154865
# ------------

# %%
# Distance metrics for linear interpolation

print('Euclidean distance: \n')
print('Empirical Bernstein: ', interpolation_distance(series, eb_sample_upscaled))
print('Uniform: ', interpolation_distance(series, uniform_sample_upscaled))
print('Online Sampler: \n', interpolation_distance(series, online_sample_upscaled))
print('------------ \n')

print('DTW distance: \n')
print('Empirical Bernstein: ', interpolation_distance(series, eb_sample_upscaled, distance = 'dtw'))
print('Uniform: ', interpolation_distance(series, uniform_sample_upscaled, distance = 'dtw'))
print('Online Sampler: \n', interpolation_distance(series, online_sample_upscaled, distance = 'dtw'))
print('------------\n')
# Out:
# Euclidean distance:
#
# Empirical Bernstein:  524.2835191325238
# Uniform:  519.2327382644913
# Online Sampler:
#  726.764098520124
# ------------
#
# DTW distance:
#
# Empirical Bernstein:  121387.1195561664
# Uniform:  122885.17867921987
# Online Sampler:
#  147155.55111367724
# ------------

# %%
# Autocorrelation

print('Autocorrelation: \n')
print('Original time series: ')
correlation_query(series, number_of_lags = 2, print_lags = True, plot = False)
print('Empirical Bernstein: ')
correlation_query(eb_sample, number_of_lags = 2, print_lags = True, plot = False)
print('Uniform: ' )
correlation_query(uniform_sample, number_of_lags = 2, print_lags = True, plot = False)
print('Online Sampler:', )
correlation_query(online_subsample, number_of_lags = 2, print_lags = True, plot = False)
print('------------ \n')
# Out:
# Autocorrelation:
#
# Original time series:
# lag 0:  0.8603300514938057
# lag 1:  0.8948285216255644
# Empirical Bernstein:
# lag 0:  0.002707506192934191
# lag 1:  0.006301781578271248
# Uniform:
# lag 0:  0.8878288299815273
# lag 1:  0.9069765214389669
# Online Sampler:
# lag 0:  0.8553510810696694
# lag 1:  0.8859025817470714
# ------------

# %%
# Distance metrics for autocorrelation

print('Euclidean distance of all autocorrelation lags: \n')
print('Empirical Bernstein: ', correlation_distance(series, eb_sample, number_of_lags = 2, print_lags = False, plot = False))
print('Uniform: ', correlation_distance(series, uniform_sample, number_of_lags = 2, print_lags = False, plot = False))
print('Online Sampler: \n', correlation_distance(series, online_subsample, number_of_lags = 2, print_lags = False, plot = False))
print('------------ \n')
# Out:
# Euclidean distance of all autocorrelation lags:
#
# Empirical Bernstein:  1.2349073641319885
# Uniform:  0.03006254676143075
# Online Sampler:
#  0.0102206922074239
# ------------

# %% [markdown]
# ## ARMA(3,1)

# %%
#Piecewise Stationary series

#Parameters
n = 100000
mu = 2
sigma = 0.5

ar = np.array([1,0.75,0.5,0.25])
ma = np.array([1,0.5])
time_series = ArmaProcess(-ar,ma)
time_series_values = time_series.generate_sample(n)

#Altered means
time_series_values[:] += 7.5
time_series_values[10000:20000] += 10
time_series_values[40000:50000] += 5
time_series_values[60000:70000] += 10
time_series_values[80000:90000] += 7.5

#plot
tidx = pd.date_range('1950-01-01', periods=n, freq='D') # freq='MS'set the frequency of date in months and start from day 1. You can use 'T' for minutes and so on
series = pd.Series(time_series_values, index =tidx)
series.plot(figsize=(10, 5))

# %%
# Online subsampler

queue = mp.Queue()
return_queue = mp.Queue()
index_queue = mp.Queue()
p1 = mp.Process(target = detection, args = (series, queue, 6, 1, False, True))
p2 = mp.Process(target = online_subsampler, args = (0.1,0.01,10,50,series, queue, return_queue,index_queue, 1000))

p1.start()
p2.start()
# Out:
# breakpoint started
# subsampler started
# Interval size:  10000
# Relative sample size:  3.0 %
# ----*----
# Interval size:  10000
# Relative sample size:  3.0 %
# ----*----
# Interval size:  9473
# Relative sample size:  4.75 %
# ----*----
# Interval size:  8002
# Relative sample size:  6.25 %
# ----*----
# Interval size:  22525
# Relative sample size:  2.22 %
# ----*----
# Interval size:  5001
# Relative sample size:  8.0 %
# ----*----
# Interval size:  4999
# Relative sample size:  8.0 %
# ----*----
# Interval size:  10000
# Relative sample size:  4.5 %
# ----*----
# Interval size:  20000
# Relative sample size:  2.25 %
# ----*----
# Done

# %%
#Subsample data
online_subsample = retrieve_data(return_queue)
online_subsample.plot(figsize=(10, 5))

# %%
#Baseline Subsamples
online_subsample_size = len(online_subsample)
uniform_sample, eb_sample = size_optimizer(series, online_subsample_size, 10, error = 0.25)

# %%
#Comparing subsample sizes
print('Online subsample size: ', online_subsample_size)
print('EB subsample size: ',len(eb_sample))
print('Uniform subsample size: ',len(uniform_sample))
# Out:
# Online subsample size:  17344
# EB subsample size:  16463
# Uniform subsample size:  20002

# %%
#upscaled subsamples
online_sample_upscaled = online_subsample.resample('D').mean()
eb_sample_upscaled = eb_sample.resample('D').mean()
uniform_sample_upscaled = uniform_sample.resample('D').mean()

# %% [markdown]
# ### Query evaluation

# %%
#interpolation querry
#10
print('Interpolation for 57th value: \n')
print('Real value: ', series[57])
print('Empirical Bernstein: ', interpolation_query(eb_sample_upscaled, 57, method = 'linear'))
print('Uniform sampler: ', interpolation_query(uniform_sample_upscaled, 57, method = 'linear'))
print('Online Sampler:', interpolation_query(online_sample_upscaled, 57, method = 'linear'))
print('------------\n')

#17400
print('Interpolation for 17400 value: \n')
print('Real value: ', series[17401])
print('Empirical Bernstein: ', interpolation_query(eb_sample_upscaled, 17401, method = 'linear'))
print('Uniform sampler: ', interpolation_query(uniform_sample_upscaled, 17401, method = 'linear'))
print('Online Sampler:', interpolation_query(online_sample_upscaled, 17401, method = 'linear'))
print('------------\n')

#1003

print('Interpolation for 1003 value: \n')
print('Real value: ', series[1003])
print('Empirical Bernstein: ', interpolation_query(eb_sample_upscaled, 1003, method = 'linear'))
print('Uniform sampler: ', interpolation_query(uniform_sample_upscaled, 1003, method = 'linear'))
print('Online Sampler:', interpolation_query(online_sample_upscaled, 1003, method = 'linear'))
print('------------\n')

#77802

print('Interpolation for 77802 value: \n')
print('Real value: ', series[77802])
print('Empirical Bernstein: ', interpolation_query(eb_sample_upscaled, 77802, method = 'linear'))
print('Uniform sampler: ', interpolation_query(uniform_sample_upscaled, 77802, method = 'linear'))
print('Online Sampler:', interpolation_query(online_sample_upscaled, 77802, method = 'linear'))
print('------------\n')
# Out:
# Interpolation for 57th value:
#
# Real value:  8.980625834316648
# Empirical Bernstein:  6.328648515953382
# Uniform sampler:  6.454513831240378
# Online Sampler: 7.898172386946618
# ------------
#
# Interpolation for 17400 value:
#
# Real value:  16.342482020449534
# Empirical Bernstein:  17.768192486896908
# Uniform sampler:  17.919704095993414
# Online Sampler: 18.012366306769955
# ------------
#
# Interpolation for 1003 value:
#
# Real value:  4.236435997821505
# Empirical Bernstein:  4.236435997821505
# Uniform sampler:  7.154432417436982
# Online Sampler: 6.888423227116293
# ------------
#
# Interpolation for 77802 value:
#
# Real value:  7.071263095040889
# Empirical Bernstein:  7.071263095040889
# Uniform sampler:  5.941462198052295
# Online Sampler: 7.179503780008797
# ------------

# %%
# Distance metrics for linear interpolation

print('Euclidean distance: \n')
print('Empirical Bernstein: ', interpolation_distance(series, eb_sample_upscaled))
print('Uniform: ', interpolation_distance(series, uniform_sample_upscaled))
print('Online Sampler: \n', interpolation_distance(series, online_sample_upscaled))
print('------------ \n')

print('DTW distance: \n')
print('Empirical Bernstein: ', interpolation_distance(series, eb_sample_upscaled, distance = 'dtw'))
print('Uniform: ', interpolation_distance(series, uniform_sample_upscaled, distance = 'dtw'))
print('Online Sampler: \n', interpolation_distance(series, online_sample_upscaled, distance = 'dtw'))
print('------------\n')
# Out:
# Euclidean distance:
#
# Empirical Bernstein:  426.1573387504447
# Uniform:  421.81572873303304
# Online Sampler:
#  767.444725242885
# ------------
#
# DTW distance:
#
# Empirical Bernstein:  98271.23417104039
# Uniform:  97138.06167720248
# Online Sampler:
#  125580.2034144421
# ------------

# %%
# Autocorrelation

print('Autocorrelation: \n')
print('Original time series: ')
correlation_query(series, number_of_lags = 3, print_lags = True, plot = False)
print('Empirical Bernstein: ')
correlation_query(eb_sample, number_of_lags = 3, print_lags = True, plot = False)
print('Uniform: ' )
correlation_query(uniform_sample, number_of_lags = 3, print_lags = True, plot = False)
print('Online Sampler:', )
correlation_query(online_subsample, number_of_lags = 3, print_lags = True, plot = False)
print('------------ \n')
# Out:
# Autocorrelation:
#
# Original time series:
# lag 0:  0.9251569571474875
# lag 1:  0.9145604641781208
# lag 2:  0.9410051035175503
# Empirical Bernstein:
# lag 0:  -0.006498535636997559
# lag 1:  0.0021378939466279875
# lag 2:  0.008481407371906715
# Uniform:
# lag 0:  0.9308585856077041
# lag 1:  0.9338103627325732
# lag 2:  0.9333817121090637
# Online Sampler:
# lag 0:  0.9295732357180972
# lag 1:  0.9173985723343677
# lag 2:  0.9351133673301618
# ------------

# %%
# Distance metrics for autocorrelation

print('Euclidean distance of all autocorrelation lags: \n')
print('Empirical Bernstein: ', correlation_distance(series, eb_sample, number_of_lags = 3, print_lags = False, plot = False))
print('Uniform: ', correlation_distance(series, uniform_sample, number_of_lags = 3, print_lags = False, plot = False))
print('Online Sampler: \n', correlation_distance(series, online_subsample, number_of_lags = 3, print_lags = False, plot = False))
print('------------ \n')
# Out:
# Euclidean distance of all autocorrelation lags:
#
# Empirical Bernstein:  1.6031523158379173
# Uniform:  0.021475177718055093
# Online Sampler:
#  0.007891193168435656
# ------------

# %% [markdown]
# ## ARMA(2,2)

# %%
#Piecewise Stationary series

#Parameters
n = 100000
mu = 2
sigma = 0.5

ar = np.array([1,0.75,0.5])
ma = np.array([1,0.5,0.25])
#time_series = ArmaProcess(ar,ma)
time_series_values = arma_generate_sample(-ar,ma,n,sigma)

#Altered means
time_series_values[:] += 7.5
time_series_values[10000:20000] += 10
time_series_values[40000:50000] += 5
time_series_values[60000:70000] += 10
time_series_values[80000:90000] += 7.5

#plot
tidx = pd.date_range('1950-01-01', periods=n, freq='D') # freq='MS'set the frequency of date in months and start from day 1. You can use 'T' for minutes and so on
series = pd.Series(time_series_values, index =tidx)
series.plot(figsize=(10, 5))

# %%
# Online subsampler

queue = mp.Queue()
return_queue = mp.Queue()
index_queue = mp.Queue()
p1 = mp.Process(target = detection, args = (series, queue, 5.5, 1, False, True))
p2 = mp.Process(target = online_subsampler, args = (0.025,0.01,10,75,series, queue, return_queue,index_queue, 1000))

p1.start()
p2.start()
# Out:
# breakpoint started
# subsampler started
# Interval size:  10000
# Relative sample size:  12.0 %
# ----*----
# Interval size:  10000
# Relative sample size:  6.0 %
# ----*----
# Interval size:  40000
# Relative sample size:  4.31 %
# ----*----
# Interval size:  10000
# Relative sample size:  11.25 %
# ----*----
# Interval size:  20000
# Relative sample size:  12.0 %
# ----*----
# Interval size:  10000
# Relative sample size:  21.0 %
# ----*----
# Done

# %%
#Subsample data
online_subsample = retrieve_data(return_queue)
online_subsample.plot(figsize=(10, 5))

# %%
#Baseline Subsamples
online_subsample_size = len(online_subsample)
uniform_sample, eb_sample = size_optimizer(series, online_subsample_size, 10, error = 0.25)

# %%
#Comparing subsample sizes
print('Online subsample size: ', online_subsample_size)
print('EB subsample size: ',len(eb_sample))
print('Uniform subsample size: ',len(uniform_sample))
# Out:
# Online subsample size:  25740
# EB subsample size:  15396
# Uniform subsample size:  33336

# %%
#upscaled subsamples
online_sample_upscaled = online_subsample.resample('D').mean()
eb_sample_upscaled = eb_sample.resample('D').mean()
uniform_sample_upscaled = uniform_sample.resample('D').mean()

# %% [markdown]
# ### Query evaluation

# %%
#interpolation querry
#10
print('Interpolation for 57th value: \n')
print('Real value: ', series[57])
print('Empirical Bernstein: ', interpolation_query(eb_sample_upscaled, 57, method = 'linear'))
print('Uniform sampler: ', interpolation_query(uniform_sample_upscaled, 57, method = 'linear'))
print('Online Sampler:', interpolation_query(online_sample_upscaled, 57, method = 'linear'))
print('------------\n')

#17400
print('Interpolation for 17400 value: \n')
print('Real value: ', series[17401])
print('Empirical Bernstein: ', interpolation_query(eb_sample_upscaled, 17401, method = 'linear'))
print('Uniform sampler: ', interpolation_query(uniform_sample_upscaled, 17401, method = 'linear'))
print('Online Sampler:', interpolation_query(online_sample_upscaled, 17401, method = 'linear'))
print('------------\n')

#1003

print('Interpolation for 1003 value: \n')
print('Real value: ', series[1003])
print('Empirical Bernstein: ', interpolation_query(eb_sample_upscaled, 1003, method = 'linear'))
print('Uniform sampler: ', interpolation_query(uniform_sample_upscaled, 1003, method = 'linear'))
print('Online Sampler:', interpolation_query(online_sample_upscaled, 1003, method = 'linear'))
print('------------\n')

#77802

print('Interpolation for 77802 value: \n')
print('Real value: ', series[77802])
print('Empirical Bernstein: ', interpolation_query(eb_sample_upscaled, 77802, method = 'linear'))
print('Uniform sampler: ', interpolation_query(uniform_sample_upscaled, 77802, method = 'linear'))
print('Online Sampler:', interpolation_query(online_sample_upscaled, 77802, method = 'linear'))
print('------------\n')
# Out:
# Interpolation for 57th value:
#
# Real value:  8.118166698438966
# Empirical Bernstein:  6.955386844683646
# Uniform sampler:  8.118166698438966
# Online Sampler: 8.208088376867812
# ------------
#
# Interpolation for 17400 value:
#
# Real value:  16.89363140005907
# Empirical Bernstein:  17.855016743316007
# Uniform sampler:  17.17595301283839
# Online Sampler: 17.23064996050345
# ------------
#
# Interpolation for 1003 value:
#
# Real value:  7.483377804895165
# Empirical Bernstein:  6.220193695771545
# Uniform sampler:  7.3186183614948375
# Online Sampler: 7.177301909486575
# ------------
#
# Interpolation for 77802 value:
#
# Real value:  6.73306234013979
# Empirical Bernstein:  6.73306234013979
# Uniform sampler:  6.73306234013979
# Online Sampler: 6.987886614567949
# ------------

# %%
# Distance metrics for linear interpolation

print('Euclidean distance: \n')
print('Empirical Bernstein: ', interpolation_distance(series, eb_sample_upscaled))
print('Uniform: ', interpolation_distance(series, uniform_sample_upscaled))
print('Online Sampler: \n', interpolation_distance(series, online_sample_upscaled))
print('------------ \n')

print('DTW distance: \n')
print('Empirical Bernstein: ', interpolation_distance(series, eb_sample_upscaled, distance = 'dtw'))
print('Uniform: ', interpolation_distance(series, uniform_sample_upscaled, distance = 'dtw'))
print('Online Sampler: \n', interpolation_distance(series, online_sample_upscaled, distance = 'dtw'))
print('------------\n')
# Out:
# Euclidean distance:
#
# Empirical Bernstein:  203.40634672101478
# Uniform:  195.19402504500005
# Online Sampler:
#  382.7155510593672
# ------------
#
# DTW distance:
#
# Empirical Bernstein:  46401.32022212879
# Uniform:  44831.29708840101
# Online Sampler:
#  57273.68978147354
# ------------

# %%
# Autocorrelation

print('Autocorrelation: \n')
print('Original time series: ')
correlation_query(series, number_of_lags = 2, print_lags = True, plot = False)
print('Empirical Bernstein: ')
correlation_query(eb_sample, number_of_lags = 2, print_lags = True, plot = False)
print('Uniform: ' )
correlation_query(uniform_sample, number_of_lags = 2, print_lags = True, plot = False)
print('Online Sampler:', )
correlation_query(online_subsample, number_of_lags = 2, print_lags = True, plot = False)
print('------------ \n')
# Out:
# Autocorrelation:
#
# Original time series:
# lag 0:  0.980470819418727
# lag 1:  0.9825176640948289
# Empirical Bernstein:
# lag 0:  0.010656017964253299
# lag 1:  -0.005402007022816544
# Uniform:
# lag 0:  0.9870445016005366
# lag 1:  0.984413631604932
# Online Sampler:
# lag 0:  0.9777925477400567
# lag 1:  0.9759091072901981
# ------------

# %%
# Distance metrics for autocorrelation

print('Euclidean distance of all autocorrelation lags: \n')
print('Empirical Bernstein: ', correlation_distance(series, eb_sample, number_of_lags = 2, print_lags = False, plot = False))
print('Uniform: ', correlation_distance(series, uniform_sample, number_of_lags = 2, print_lags = False, plot = False))
print('Online Sampler: \n', correlation_distance(series, online_subsample, number_of_lags = 2, print_lags = False, plot = False))
print('------------ \n')
# Out:
# Euclidean distance of all autocorrelation lags:
#
# Empirical Bernstein:  1.3843865160067752
# Uniform:  0.00684163651671198
# Online Sampler:
#  0.007130649495298404
# ------------

# %%
#Verifying Arma models
#model = ARMA(time_series_values, (2, 2)).fit(trend='nc', disp=0)
model_uniform_sample = ARMA(uniform_sample, (2, 2)).fit(trend='nc', disp=0)
#model_eb_sample = ARMA(eb_sample, (2, 2)).fit(trend='nc', disp=0)
model_online_sample = ARMA(online_subsample, (2, 2)).fit(trend='nc', disp=0)

# %%
#Parameters
#ar = np.array([1,0.75,0.5])
#ma = np.array([1,0.5,0.25])
print('original model: ', model.params)
print('uniform sample model: ', model_uniform_sample.params)
#print('eb model: ', model_eb_sample.params)
print('online model: ', model_online_sample.params)

# %% [markdown]
# ## Varying block size

# %%
#Piecewise Stationary series

#Parameters
n = 100000
mu = 2
sigma = 0.5

ar = np.array([1,0.75,0.5])
ma = np.array([1])
#time_series = ArmaProcess(ar,ma)
time_series_values = arma_generate_sample(-ar,ma,n,sigma)

#Altered means
time_series_values[:] += 7.5
time_series_values[10000:20000] += 10
time_series_values[40000:50000] += 5
time_series_values[60000:70000] += 10
time_series_values[80000:90000] += 7.5

#plot
tidx = pd.date_range('1950-01-01', periods=n, freq='D') # freq='MS'set the frequency of date in months and start from day 1. You can use 'T' for minutes and so on
series = pd.Series(time_series_values, index =tidx)
series.plot(figsize=(10, 5))

# %%
# Online subsampler

queue = mp.Queue()
return_queue = mp.Queue()
index_queue = mp.Queue()
p1 = mp.Process(target = detection, args = (series, queue, 6, 1, False, True))
p2 = mp.Process(target = online_subsampler, args = (0.15,0.01,14,50,series, queue, return_queue,index_queue, 1000))

p1.start()
p2.start()
# Out:
# breakpoint started
# subsampler started
# Interval size:  10000
# Relative sample size:  2.25 %
# ----*----
# Interval size:  10000
# Relative sample size:  2.25 %
# ----*----
# Interval size:  40000
# Relative sample size:  0.81 %
# ----*----
# Interval size:  10000
# Relative sample size:  2.75 %
# ----*----
# Interval size:  10000
# Relative sample size:  3.0 %
# ----*----
# Interval size:  10000
# Relative sample size:  2.75 %
# ----*----
# Interval size:  10000
# Relative sample size:  3.0 %
# ----*----
# Done

# %%
#Subsample data
online_subsample = retrieve_data(return_queue)
online_subsample.plot(figsize=(10, 5))

# %%
#Baseline Subsamples
online_subsample_size = len(online_subsample)
uniform_sample, eb_sample = size_optimizer(series, online_subsample_size, 10, error = 0.25)

# %%
#Comparing subsample sizes
print('Online subsample size: ', online_subsample_size)
print('EB subsample size: ',len(eb_sample))
print('Uniform subsample size: ',len(uniform_sample))
# Out:
# Online subsample size:  7411
# EB subsample size:  15279
# Uniform subsample size:  7695

# %%
# Autocorrelation

print('Autocorrelation: \n')
print('Original time series: ')
correlation_query(series, number_of_lags = 2, print_lags = True, plot = False)
print('Empirical Bernstein: ')
correlation_query(eb_sample, number_of_lags = 2, print_lags = True, plot = False)
print('Uniform: ' )
correlation_query(uniform_sample, number_of_lags = 2, print_lags = True, plot = False)
print('Online Sampler:', )
correlation_query(online_subsample, number_of_lags = 2, print_lags = True, plot = False)
print('------------ \n')
# Out:
# Autocorrelation:
#
# Original time series:
# lag 0:  0.9633813676401103
# lag 1:  0.9723695532953119
# Empirical Bernstein:
# lag 0:  0.006706026826078584
# lag 1:  0.0031786818277194
# Uniform:
# lag 0:  0.9733445634823238
# lag 1:  0.9717258735990711
# Online Sampler:
# lag 0:  0.9649283693298405
# lag 1:  0.9640489573680441
# ------------

# %%
# Distance metrics for autocorrelation

print('Euclidean distance of all autocorrelation lags: \n')
print('Empirical Bernstein: ', correlation_distance(series, eb_sample, number_of_lags = 2, print_lags = False, plot = False))
print('Uniform: ', correlation_distance(series, uniform_sample, number_of_lags = 2, print_lags = False, plot = False))
print('Online Sampler: \n', correlation_distance(series, online_subsample, number_of_lags = 2, print_lags = False, plot = False))
print('------------ \n')
# Out:
# Euclidean distance of all autocorrelation lags:
#
# Empirical Bernstein:  1.3618218139895377
# Uniform:  0.009983966894058345
# Online Sampler:
#  0.008463186800070919
# ------------

# %%
#Verifying Arma models
#model = ARMA(time_series_values, (2, 2)).fit(trend='nc', disp=0)
model_uniform_sample = ARMA(uniform_sample, (2, 0)).fit(trend='nc', disp=0)
#model_eb_sample = ARMA(eb_sample, (2, 2)).fit(trend='nc', disp=0)
model_online_sample = ARMA(online_subsample, (2, 0)).fit(trend='nc', disp=0)

# %%
#Parameters
#ar = np.array([1,0.75,0.5])
#print('original model: ', model.params)
print('uniform sample model: ', model_uniform_sample.params)
#print('eb model: ', model_eb_sample.params)
print('online model: ', model_online_sample.params)
# Out:
# uniform sample model:  ar.L1.y    0.529360
# ar.L2.y    0.468633
# dtype: float64
# online model:  ar.L1.y    0.511161
# ar.L2.y    0.486088
# dtype: float64

# %% [markdown]
# ## Simplest possible model

# %%
#Piecewise Stationary series

#Parameters
n = 100000
mu = 2
sigma = 0.5

ar = np.array([1,0.75,0.5])
ma = np.array([1])
#time_series = ArmaProcess(ar,ma)
time_series_values = arma_generate_sample(-ar,ma,n,sigma)
time_series_values[:] += 7.5

#plot
tidx = pd.date_range('1950-01-01', periods=n, freq='D') # freq='MS'set the frequency of date in months and start from day 1. You can use 'T' for minutes and so on
series = pd.Series(time_series_values, index =tidx)
series.plot(figsize=(10, 5))

# %%
# Online subsampler

queue = mp.Queue()
return_queue = mp.Queue()
index_queue = mp.Queue()
p1 = mp.Process(target = detection, args = (series, queue, 6, 1, False, True))
p2 = mp.Process(target = online_subsampler, args = (0.05,0.01,14,50,series, queue, return_queue,index_queue, 1000))

p1.start()
p2.start()
# Out:
# breakpoint started
# subsampler started
# Interval size:  100000
# Relative sample size:  0.8 %
# ----*----
# Done

# %%
#Subsample data
online_subsample = retrieve_data(return_queue)
online_subsample.plot(figsize=(10, 5))

# %%
#Baseline Subsamples
online_subsample_size = len(online_subsample)
uniform_sample, eb_sample = size_optimizer(series, online_subsample_size, 10, error = 0.25)

# %%
#Comparing subsample sizes
print('Online subsample size: ', online_subsample_size)
print('EB subsample size: ',len(eb_sample))
print('Uniform subsample size: ',len(uniform_sample))
# Out:
# Online subsample size:  802
# EB subsample size:  737
# Uniform subsample size:  809

# %%
# Autocorrelation

print('Autocorrelation: \n')
print('Original time series: ')
correlation_query(series, number_of_lags = 2, print_lags = True, plot = False)
print('Empirical Bernstein: ')
correlation_query(eb_sample, number_of_lags = 2, print_lags = True, plot = False)
print('Uniform: ' )
correlation_query(uniform_sample, number_of_lags = 2, print_lags = True, plot = False)
print('Online Sampler:', )
correlation_query(online_subsample, number_of_lags = 2, print_lags = True, plot = False)
print('------------ \n')
# Out:
# Autocorrelation:
#
# Original time series:
# lag 0:  -0.49683454514556336
# lag 1:  -0.12902388950271057
# Empirical Bernstein:
# lag 0:  0.027628710137285573
# lag 1:  -0.003400354966058403
# Uniform:
# lag 0:  -0.00023683258517036306
# lag 1:  -0.04053362132639441
# Online Sampler:
# lag 0:  -0.5055038790995932
# lag 1:  -0.10360654039443137
# ------------

# %%
#Verifying Arma models
model = ARMA(time_series_values, (2,0)).fit(trend='nc', disp=0)
model_uniform_sample = ARMA(uniform_sample, (2, 0)).fit(trend='nc', disp=0)
model_eb_sample = ARMA(eb_sample, (2,0)).fit(trend='nc', disp=0)
model_online_sample = ARMA(online_subsample, (2, 0)).fit(trend='nc', disp=0)

# %%
#Parameters
#ar = np.array([1,0.75,0.5])
print('original model: ', model.params)
print('uniform sample model: ', model_uniform_sample.params)
print('eb model: ', model_eb_sample.params)
print('online model: ', model_online_sample.params)
# Out:
# original model:  [0.37493866 0.6206537 ]
# uniform sample model:  ar.L1.y    0.518570
# ar.L2.y    0.477551
# dtype: float64
# eb model:  ar.L1.y    0.514545
# ar.L2.y    0.481631
# dtype: float64
# online model:  ar.L1.y    0.364322
# ar.L2.y    0.631488
# dtype: float64

# %% [markdown]
# ## Second simple model

# %%
#Piecewise Stationary series

#Parameters
n = 100000
mu = 2
sigma = 0.5

ar = np.array([1,0.75,0.5, 0.25])
ma = np.array([1])
#time_series = ArmaProcess(ar,ma)
time_series_values = arma_generate_sample(-ar,ma,n,sigma)
time_series_values[:] += 7.5

#plot
tidx = pd.date_range('1950-01-01', periods=n, freq='D') # freq='MS'set the frequency of date in months and start from day 1. You can use 'T' for minutes and so on
series = pd.Series(time_series_values, index =tidx)
series.plot(figsize=(10, 5))

# %%
# Online subsampler

queue = mp.Queue()
return_queue = mp.Queue()
index_queue = mp.Queue()
p1 = mp.Process(target = detection, args = (series, queue, 6, 1, False, True))
p2 = mp.Process(target = online_subsampler, args = (0.05,0.01,5,50,series, queue, return_queue,index_queue, 1000))

p1.start()
p2.start()
# Out:
# breakpoint started
# subsampler started
# Interval size:  100000
# Relative sample size:  0.35 %
# ----*----
# Done

# %%
#Subsample data
online_subsample = retrieve_data(return_queue)
online_subsample.plot(figsize=(10, 5))

# %%
#Baseline Subsamples
online_subsample_size = len(online_subsample)
uniform_sample, eb_sample = size_optimizer(series, online_subsample_size, 10, error = 0.1)

# %%
#Comparing subsample sizes
print('Online subsample size: ', online_subsample_size)
print('EB subsample size: ',len(eb_sample))
print('Uniform subsample size: ',len(uniform_sample))
# Out:
# Online subsample size:  352
# EB subsample size:  328
# Uniform subsample size:  355

# %%
# Autocorrelation

print('Autocorrelation: \n')
print('Original time series: ')
correlation_query(series, number_of_lags = 2, print_lags = True, plot = False)
print('Empirical Bernstein: ')
correlation_query(eb_sample, number_of_lags = 2, print_lags = True, plot = False)
print('Uniform: ' )
correlation_query(uniform_sample, number_of_lags = 2, print_lags = True, plot = False)
print('Online Sampler:', )
correlation_query(online_subsample, number_of_lags = 2, print_lags = True, plot = False)
print('------------ \n')
# Out:
# Autocorrelation:
#
# Original time series:
# lag 0:  -0.49991817665011884
# lag 1:  -0.00231761572930093
# Empirical Bernstein:
# lag 0:  0.022789289796234135
# lag 1:  -0.017402887528517662
# Uniform:
# lag 0:  -0.08784278630668658
# lag 1:  0.037537080211709234
# Online Sampler:
# lag 0:  -0.4806870335599857
# lag 1:  -0.02352250890123992
# ------------

# %%
# Distance metrics for autocorrelation

print('Euclidean distance of all autocorrelation lags: \n')
print('Empirical Bernstein: ', correlation_distance(series, eb_sample, number_of_lags = 3, print_lags = False, plot = False))
print('Uniform: ', correlation_distance(series, uniform_sample, number_of_lags = 3, print_lags = False, plot = False))
print('Online Sampler: \n', correlation_distance(series, online_subsample, number_of_lags = 3, print_lags = False, plot = False))
print('------------ \n')
# Out:
# Euclidean distance of all autocorrelation lags:
#
# Empirical Bernstein:  0.5256495949978324
# Uniform:  0.4145350536767385
# Online Sampler:
#  0.07346975685813294
# ------------

# %%
#Verifying Arma models
model = ARMA(time_series_values, (3,0)).fit(trend='nc', disp=0)
model_uniform_sample = ARMA(uniform_sample, (3, 0)).fit(trend='nc', disp=0)
model_eb_sample = ARMA(eb_sample, (3,0)).fit(trend='nc', disp=0)
model_online_sample = ARMA(online_subsample, (3, 0)).fit(trend='nc', disp=0)

# %%
#Parameters
#ar = np.array([1,0.75,0.5, 0.25])
print('original model: ', model.params)
print('uniform sample model: ', model_uniform_sample.params)
print('eb model: ', model_eb_sample.params)
print('online model: ', model_online_sample.params)
# Out:
# original model:  [-0.00138305  0.49707607  0.50253264]
# uniform sample model:  ar.L1.y    0.255278
# ar.L2.y    0.411390
# ar.L3.y    0.330812
# dtype: float64
# eb model:  ar.L1.y    0.373142
# ar.L2.y    0.318004
# ar.L3.y    0.306432
# dtype: float64
# online model:  ar.L1.y   -0.011251
# ar.L2.y    0.469559
# ar.L3.y    0.540019
# dtype: float64
